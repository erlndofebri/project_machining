# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier

from sklearn.metrics import classification_report, ConfusionMatrixDisplay, roc_curve, roc_auc_score, f1_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.dummy import DummyClassifier


import numpy as np


from datetime import datetime
from tqdm import tqdm
import yaml
import joblib
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import copy
import hashlib

# %% [markdown]
# # 1. Load Params

# %%
params_dir = "config/config.yaml"

# %%
def load_params(param_dir):
    "Function to read params config"
    with open(param_dir, 'r') as file:
        params = yaml.safe_load(file)
        
    return params

# %%
params = load_params(params_dir)

# %% [markdown]
# # 2. Load Dataset

# %%
x_train = joblib.load("data/processed/x_train_feng.pkl")
y_train = joblib.load("data/processed/y_train_feng.pkl")

x_valid = joblib.load("data/processed/x_valid_feng.pkl")
y_valid = joblib.load("data/processed/y_valid_feng.pkl")

x_test = joblib.load("data/processed/x_test_feng.pkl")
y_test = joblib.load("data/processed/y_test_feng.pkl")

# %%
x_train.head()
# Out:
#    Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0             0.645921                 0.402959               -0.543586
# 1             1.195562                 0.740340                1.959851
# 2             1.095627                 0.740340               -1.042033
# 3            -0.303458                -0.609183               -0.918822
# 4             1.245529                 1.280149               -0.095544
#
#    Torque [Nm]  Tool wear [min]    Type_H    Type_L    Type_M
# 0     1.379991        -0.281424 -0.328918  0.814372 -0.656408
# 1    -1.779083         1.401429 -0.328918 -1.227940  1.523443
# 2     0.856832         0.033128 -0.328918  0.814372 -0.656408
# 3     0.404099        -0.422972  3.040276 -1.227940 -0.656408
# 4     0.484585        -0.218513 -0.328918  0.814372 -0.656408

# %% [markdown]
# # 3. Create Model

# %%
def create_model_param():
    """Create the model objects"""
    knn_params = {
        'n_neighbors': [50, 100, 200],
    }
    
    lgr_params = {
        'penalty': ['l1', 'l2'],
        'C': [0.01, 0.1],
        'max_iter': [100, 300, 500]
    }

    dt_params = {
        'min_samples_split': [2, 5, 10, 25, 50]
    }

    # Create model params
    list_of_param = {
        'KNeighborsClassifier': knn_params,
        'LogisticRegression': lgr_params,
        'DecisionTreeClassifier': dt_params
    }

    return list_of_param

# %%
def create_model_object():
    """Create the model objects"""
    print("Creating model objects")

    # Create model objects
    knn = KNeighborsClassifier()
    lgr = LogisticRegression(solver='liblinear')
    dt = DecisionTreeClassifier()

    # Create list of model
    list_of_model = [
        {'model_name': knn.__class__.__name__, 'model_object': knn},
        {'model_name': lgr.__class__.__name__, 'model_object': lgr},
        {'model_name': dt.__class__.__name__, 'model_object': dt}
    ]

    return list_of_model

# %%
lgr_params = {
        'C': [0.01, 0.1],
        'max_iter': [100, 300, 500]
    }

# %%
# Create model object
model = RandomizedSearchCV(estimator = LogisticRegression(solver = 'liblinear'),
                            param_distributions = lgr_params,
                            n_iter=5,
                            cv = 5,
                            random_state = 123,
                            n_jobs=1,
                            verbose=10,
                            scoring = 'roc_auc')

# Train model
model.fit(x_train, y_train)

# Predict
y_pred_proba_train = model.predict_proba(x_train)[:, 1]
y_pred_proba_valid = model.predict_proba(x_valid)[:, 1]

# Get score
train_score = roc_auc_score(y_train, y_pred_proba_train)
valid_score = roc_auc_score(y_valid, y_pred_proba_valid)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5; 1/5] START C=0.01, max_iter=300........................................
# [CV 1/5; 1/5] END .........C=0.01, max_iter=300;, score=0.882 total time=   0.0s
# [CV 2/5; 1/5] START C=0.01, max_iter=300........................................
# [CV 2/5; 1/5] END .........C=0.01, max_iter=300;, score=0.838 total time=   0.0s
# [CV 3/5; 1/5] START C=0.01, max_iter=300........................................
# [CV 3/5; 1/5] END .........C=0.01, max_iter=300;, score=0.837 total time=   0.0s
# [CV 4/5; 1/5] START C=0.01, max_iter=300........................................
# [CV 4/5; 1/5] END .........C=0.01, max_iter=300;, score=0.895 total time=   0.0s
# [CV 5/5; 1/5] START C=0.01, max_iter=300........................................
# [CV 5/5; 1/5] END .........C=0.01, max_iter=300;, score=0.874 total time=   0.0s
# [CV 1/5; 2/5] START C=0.1, max_iter=100.........................................
# [CV 1/5; 2/5] END ..........C=0.1, max_iter=100;, score=0.887 total time=   0.0s
# [CV 2/5; 2/5] START C=0.1, max_iter=100.........................................
# [CV 2/5; 2/5] END ..........C=0.1, max_iter=100;, score=0.916 total time=   0.0s
# [CV 3/5; 2/5] START C=0.1, max_iter=100.........................................
# [CV 3/5; 2/5] END ..........C=0.1, max_iter=100;, score=0.854 total time=   0.0s
# [CV 4/5; 2/5] START C=0.1, max_iter=100.........................................
# [CV 4/5; 2/5] END ..........C=0.1, max_iter=100;, score=0.908 total time=   0.0s
# [CV 5/5; 2/5] START C=0.1, max_iter=100.........................................
# [CV 5/5; 2/5] END ..........C=0.1, max_iter=100;, score=0.873 total time=   0.0s
# [CV 1/5; 3/5] START C=0.1, max_iter=300.........................................
# [CV 1/5; 3/5] END ..........C=0.1, max_iter=300;, score=0.887 total time=   0.0s
# [CV 2/5; 3/5] START C=0.1, max_iter=300.........................................
# [CV 2/5; 3/5] END ..........C=0.1, max_iter=300;, score=0.916 total time=   0.0s
# [CV 3/5; 3/5] START C=0.1, max_iter=300.........................................
# [CV 3/5; 3/5] END ..........C=0.1, max_iter=300;, score=0.854 total time=   0.0s
# [CV 4/5; 3/5] START C=0.1, max_iter=300.........................................
# [CV 4/5; 3/5] END ..........C=0.1, max_iter=300;, score=0.908 total time=   0.0s
# [CV 5/5; 3/5] START C=0.1, max_iter=300.........................................
# [CV 5/5; 3/5] END ..........C=0.1, max_iter=300;, score=0.873 total time=   0.0s
# [CV 1/5; 4/5] START C=0.01, max_iter=100........................................
# [CV 1/5; 4/5] END .........C=0.01, max_iter=100;, score=0.882 total time=   0.0s
# [CV 2/5; 4/5] START C=0.01, max_iter=100........................................
# [CV 2/5; 4/5] END .........C=0.01, max_iter=100;, score=0.838 total time=   0.0s
# [CV 3/5; 4/5] START C=0.01, max_iter=100........................................
# [CV 3/5; 4/5] END .........C=0.01, max_iter=100;, score=0.837 total time=   0.0s
# [CV 4/5; 4/5] START C=0.01, max_iter=100........................................
# [CV 4/5; 4/5] END .........C=0.01, max_iter=100;, score=0.895 total time=   0.0s
# [CV 5/5; 4/5] START C=0.01, max_iter=100........................................
# [CV 5/5; 4/5] END .........C=0.01, max_iter=100;, score=0.874 total time=   0.0s
# [CV 1/5; 5/5] START C=0.01, max_iter=500........................................
# [CV 1/5; 5/5] END .........C=0.01, max_iter=500;, score=0.882 total time=   0.0s
# [CV 2/5; 5/5] START C=0.01, max_iter=500........................................
# [CV 2/5; 5/5] END .........C=0.01, max_iter=500;, score=0.838 total time=   0.0s
# [CV 3/5; 5/5] START C=0.01, max_iter=500........................................
# [CV 3/5; 5/5] END .........C=0.01, max_iter=500;, score=0.837 total time=   0.0s
# [CV 4/5; 5/5] START C=0.01, max_iter=500........................................
# [CV 4/5; 5/5] END .........C=0.01, max_iter=500;, score=0.895 total time=   0.0s
# [CV 5/5; 5/5] START C=0.01, max_iter=500........................................
# [CV 5/5; 5/5] END .........C=0.01, max_iter=500;, score=0.874 total time=   0.0s

# %%
def train_model(return_file=True):
    """Function to get the best model"""
    # Load dataset
    X_train = joblib.load(params['train_feng_set_path'][0])
    y_train = joblib.load(params['train_feng_set_path'][1])
    X_valid = joblib.load(params['valid_feng_set_path'][0])
    y_valid = joblib.load(params['valid_feng_set_path'][1])
    
    # Create list of params & models
    list_of_param = create_model_param()
    list_of_model = create_model_object()

    # List of trained model
    list_of_tuned_model = {}

    # Train model
    for base_model in list_of_model:
        # Current condition
        model_name = base_model['model_name']
        model_obj = copy.deepcopy(base_model['model_object'])
        model_param = list_of_param[model_name]

        # Debug message
        print('Training model :', model_name)

        # Create model object
        model = RandomizedSearchCV(estimator = model_obj,
                                   param_distributions = model_param,
                                   n_iter=5,
                                   cv = 5,
                                   random_state = 123,
                                   n_jobs=1,
                                   verbose=10,
                                   scoring = 'roc_auc')
        
        # Train model
        model.fit(X_train, y_train)

        # Predict
        y_pred_proba_train = model.predict_proba(X_train)[:, 1]
        y_pred_proba_valid = model.predict_proba(X_valid)[:, 1]
        
        # Get score
        train_score = roc_auc_score(y_train, y_pred_proba_train)
        valid_score = roc_auc_score(y_valid, y_pred_proba_valid)

        # Append
        list_of_tuned_model[model_name] = {
            'model': model,
            'train_auc': train_score,
            'valid_auc': valid_score,
            'best_params': model.best_params_
        }

        print("Done training")
        print("")
   
    # Dump data
    joblib.dump(list_of_param, params['list_of_param_path'])
    joblib.dump(list_of_model, params['list_of_model_path'])
    joblib.dump(list_of_tuned_model, params['list_of_tuned_model_path'])


    if return_file:
        return list_of_param, list_of_model, list_of_tuned_model

# %%
list_of_param, list_of_model, list_of_tuned_model = train_model()
# Out:
# Creating model objects
# Training model : KNeighborsClassifier
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5; 1/3] START n_neighbors=50..............................................
# [CV 1/5; 1/3] END ...............n_neighbors=50;, score=0.948 total time=   0.1s
# [CV 2/5; 1/3] START n_neighbors=50..............................................
# c:\Users\ThinkPad\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:306: UserWarning: The total space of parameters 3 is smaller than n_iter=5. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# [CV 2/5; 1/3] END ...............n_neighbors=50;, score=0.921 total time=   0.1s
# [CV 3/5; 1/3] START n_neighbors=50..............................................
# [CV 3/5; 1/3] END ...............n_neighbors=50;, score=0.912 total time=   0.2s
# [CV 4/5; 1/3] START n_neighbors=50..............................................
# [CV 4/5; 1/3] END ...............n_neighbors=50;, score=0.898 total time=   0.0s
# [CV 5/5; 1/3] START n_neighbors=50..............................................
# [CV 5/5; 1/3] END ...............n_neighbors=50;, score=0.933 total time=   0.0s
# [CV 1/5; 2/3] START n_neighbors=100.............................................
# [CV 1/5; 2/3] END ..............n_neighbors=100;, score=0.951 total time=   0.1s
# [CV 2/5; 2/3] START n_neighbors=100.............................................
# [CV 2/5; 2/3] END ..............n_neighbors=100;, score=0.914 total time=   0.1s
# [CV 3/5; 2/3] START n_neighbors=100.............................................
# [CV 3/5; 2/3] END ..............n_neighbors=100;, score=0.904 total time=   0.0s
# [CV 4/5; 2/3] START n_neighbors=100.............................................
# [CV 4/5; 2/3] END ..............n_neighbors=100;, score=0.882 total time=   0.1s
# [CV 5/5; 2/3] START n_neighbors=100.............................................
# [CV 5/5; 2/3] END ..............n_neighbors=100;, score=0.939 total time=   0.1s
# [CV 1/5; 3/3] START n_neighbors=200.............................................
# [CV 1/5; 3/3] END ..............n_neighbors=200;, score=0.949 total time=   0.2s
# [CV 2/5; 3/3] START n_neighbors=200.............................................
# [CV 2/5; 3/3] END ..............n_neighbors=200;, score=0.893 total time=   0.2s
# [CV 3/5; 3/3] START n_neighbors=200.............................................
# [CV 3/5; 3/3] END ..............n_neighbors=200;, score=0.895 total time=   0.2s
# [CV 4/5; 3/3] START n_neighbors=200.............................................
# [CV 4/5; 3/3] END ..............n_neighbors=200;, score=0.904 total time=   0.1s
# [CV 5/5; 3/3] START n_neighbors=200.............................................
# [CV 5/5; 3/3] END ..............n_neighbors=200;, score=0.934 total time=   0.1s
# Done training
#
# Training model : LogisticRegression
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5; 1/5] START C=0.01, max_iter=500, penalty=l2............................
# [CV 1/5; 1/5] END C=0.01, max_iter=500, penalty=l2;, score=0.882 total time=   0.0s
# [CV 2/5; 1/5] START C=0.01, max_iter=500, penalty=l2............................
# [CV 2/5; 1/5] END C=0.01, max_iter=500, penalty=l2;, score=0.838 total time=   0.0s
# [CV 3/5; 1/5] START C=0.01, max_iter=500, penalty=l2............................
# [CV 3/5; 1/5] END C=0.01, max_iter=500, penalty=l2;, score=0.837 total time=   0.0s
# [CV 4/5; 1/5] START C=0.01, max_iter=500, penalty=l2............................
# [CV 4/5; 1/5] END C=0.01, max_iter=500, penalty=l2;, score=0.895 total time=   0.0s
# [CV 5/5; 1/5] START C=0.01, max_iter=500, penalty=l2............................
# [CV 5/5; 1/5] END C=0.01, max_iter=500, penalty=l2;, score=0.874 total time=   0.0s
# [CV 1/5; 2/5] START C=0.01, max_iter=100, penalty=l1............................
# [CV 1/5; 2/5] END C=0.01, max_iter=100, penalty=l1;, score=0.816 total time=   0.0s
# [CV 2/5; 2/5] START C=0.01, max_iter=100, penalty=l1............................
# [CV 2/5; 2/5] END C=0.01, max_iter=100, penalty=l1;, score=0.752 total time=   0.0s
# [CV 3/5; 2/5] START C=0.01, max_iter=100, penalty=l1............................
# [CV 3/5; 2/5] END C=0.01, max_iter=100, penalty=l1;, score=0.747 total time=   0.0s
# [CV 4/5; 2/5] START C=0.01, max_iter=100, penalty=l1............................
# [CV 4/5; 2/5] END C=0.01, max_iter=100, penalty=l1;, score=0.835 total time=   0.0s
# [CV 5/5; 2/5] START C=0.01, max_iter=100, penalty=l1............................
# [CV 5/5; 2/5] END C=0.01, max_iter=100, penalty=l1;, score=0.844 total time=   0.0s
# [CV 1/5; 3/5] START C=0.01, max_iter=500, penalty=l1............................
# [CV 1/5; 3/5] END C=0.01, max_iter=500, penalty=l1;, score=0.816 total time=   0.0s
# [CV 2/5; 3/5] START C=0.01, max_iter=500, penalty=l1............................
# [CV 2/5; 3/5] END C=0.01, max_iter=500, penalty=l1;, score=0.752 total time=   0.0s
# [CV 3/5; 3/5] START C=0.01, max_iter=500, penalty=l1............................
# [CV 3/5; 3/5] END C=0.01, max_iter=500, penalty=l1;, score=0.747 total time=   0.0s
# [CV 4/5; 3/5] START C=0.01, max_iter=500, penalty=l1............................
# [CV 4/5; 3/5] END C=0.01, max_iter=500, penalty=l1;, score=0.835 total time=   0.0s
# [CV 5/5; 3/5] START C=0.01, max_iter=500, penalty=l1............................
# [CV 5/5; 3/5] END C=0.01, max_iter=500, penalty=l1;, score=0.844 total time=   0.0s
# [CV 1/5; 4/5] START C=0.1, max_iter=300, penalty=l2.............................
# [CV 1/5; 4/5] END C=0.1, max_iter=300, penalty=l2;, score=0.887 total time=   0.0s
# [CV 2/5; 4/5] START C=0.1, max_iter=300, penalty=l2.............................
# [CV 2/5; 4/5] END C=0.1, max_iter=300, penalty=l2;, score=0.916 total time=   0.0s
# [CV 3/5; 4/5] START C=0.1, max_iter=300, penalty=l2.............................
# [CV 3/5; 4/5] END C=0.1, max_iter=300, penalty=l2;, score=0.854 total time=   0.0s
# [CV 4/5; 4/5] START C=0.1, max_iter=300, penalty=l2.............................
# [CV 4/5; 4/5] END C=0.1, max_iter=300, penalty=l2;, score=0.908 total time=   0.0s
# [CV 5/5; 4/5] START C=0.1, max_iter=300, penalty=l2.............................
# [CV 5/5; 4/5] END C=0.1, max_iter=300, penalty=l2;, score=0.873 total time=   0.0s
# [CV 1/5; 5/5] START C=0.1, max_iter=300, penalty=l1.............................
# [CV 1/5; 5/5] END C=0.1, max_iter=300, penalty=l1;, score=0.881 total time=   0.0s
# [CV 2/5; 5/5] START C=0.1, max_iter=300, penalty=l1.............................
# [CV 2/5; 5/5] END C=0.1, max_iter=300, penalty=l1;, score=0.917 total time=   0.0s
# [CV 3/5; 5/5] START C=0.1, max_iter=300, penalty=l1.............................
# [CV 3/5; 5/5] END C=0.1, max_iter=300, penalty=l1;, score=0.848 total time=   0.0s
# [CV 4/5; 5/5] START C=0.1, max_iter=300, penalty=l1.............................
# [CV 4/5; 5/5] END C=0.1, max_iter=300, penalty=l1;, score=0.907 total time=   0.0s
# [CV 5/5; 5/5] START C=0.1, max_iter=300, penalty=l1.............................
# [CV 5/5; 5/5] END C=0.1, max_iter=300, penalty=l1;, score=0.872 total time=   0.0s
# Done training
#
# Training model : DecisionTreeClassifier
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5; 1/5] START min_samples_split=2.........................................
# [CV 1/5; 1/5] END ..........min_samples_split=2;, score=0.845 total time=   0.0s
# [CV 2/5; 1/5] START min_samples_split=2.........................................
# [CV 2/5; 1/5] END ..........min_samples_split=2;, score=0.848 total time=   0.0s
# [CV 3/5; 1/5] START min_samples_split=2.........................................
# [CV 3/5; 1/5] END ..........min_samples_split=2;, score=0.812 total time=   0.0s
# [CV 4/5; 1/5] START min_samples_split=2.........................................
# [CV 4/5; 1/5] END ..........min_samples_split=2;, score=0.789 total time=   0.0s
# [CV 5/5; 1/5] START min_samples_split=2.........................................
# [CV 5/5; 1/5] END ..........min_samples_split=2;, score=0.843 total time=   0.0s
# [CV 1/5; 2/5] START min_samples_split=5.........................................
# [CV 1/5; 2/5] END ..........min_samples_split=5;, score=0.856 total time=   0.0s
# [CV 2/5; 2/5] START min_samples_split=5.........................................
# [CV 2/5; 2/5] END ..........min_samples_split=5;, score=0.849 total time=   0.0s
# [CV 3/5; 2/5] START min_samples_split=5.........................................
# [CV 3/5; 2/5] END ..........min_samples_split=5;, score=0.833 total time=   0.0s
# [CV 4/5; 2/5] START min_samples_split=5.........................................
# [CV 4/5; 2/5] END ..........min_samples_split=5;, score=0.789 total time=   0.0s
# [CV 5/5; 2/5] START min_samples_split=5.........................................
# [CV 5/5; 2/5] END ..........min_samples_split=5;, score=0.861 total time=   0.0s
# [CV 1/5; 3/5] START min_samples_split=10........................................
# [CV 1/5; 3/5] END .........min_samples_split=10;, score=0.883 total time=   0.0s
# [CV 2/5; 3/5] START min_samples_split=10........................................
# [CV 2/5; 3/5] END .........min_samples_split=10;, score=0.855 total time=   0.0s
# [CV 3/5; 3/5] START min_samples_split=10........................................
# [CV 3/5; 3/5] END .........min_samples_split=10;, score=0.839 total time=   0.0s
# [CV 4/5; 3/5] START min_samples_split=10........................................
# [CV 4/5; 3/5] END .........min_samples_split=10;, score=0.798 total time=   0.0s
# [CV 5/5; 3/5] START min_samples_split=10........................................
# [CV 5/5; 3/5] END .........min_samples_split=10;, score=0.886 total time=   0.0s
# [CV 1/5; 4/5] START min_samples_split=25........................................
# [CV 1/5; 4/5] END .........min_samples_split=25;, score=0.907 total time=   0.0s
# [CV 2/5; 4/5] START min_samples_split=25........................................
# [CV 2/5; 4/5] END .........min_samples_split=25;, score=0.871 total time=   0.0s
# [CV 3/5; 4/5] START min_samples_split=25........................................
# [CV 3/5; 4/5] END .........min_samples_split=25;, score=0.891 total time=   0.0s
# [CV 4/5; 4/5] START min_samples_split=25........................................
# [CV 4/5; 4/5] END .........min_samples_split=25;, score=0.848 total time=   0.0s
# [CV 5/5; 4/5] START min_samples_split=25........................................
# [CV 5/5; 4/5] END .........min_samples_split=25;, score=0.893 total time=   0.0s
# [CV 1/5; 5/5] START min_samples_split=50........................................
# [CV 1/5; 5/5] END .........min_samples_split=50;, score=0.952 total time=   0.0s
# [CV 2/5; 5/5] START min_samples_split=50........................................
# [CV 2/5; 5/5] END .........min_samples_split=50;, score=0.901 total time=   0.0s
# [CV 3/5; 5/5] START min_samples_split=50........................................
# [CV 3/5; 5/5] END .........min_samples_split=50;, score=0.905 total time=   0.0s
# [CV 4/5; 5/5] START min_samples_split=50........................................
# [CV 4/5; 5/5] END .........min_samples_split=50;, score=0.878 total time=   0.0s
# [CV 5/5; 5/5] START min_samples_split=50........................................
# [CV 5/5; 5/5] END .........min_samples_split=50;, score=0.916 total time=   0.0s
# Done training

# %%
def get_best_model(return_file=True):
    """Function to get the best model"""
    # Load tuned model
    list_of_tuned_model = joblib.load(params['list_of_tuned_model_path'])

    # Get the best model
    best_model_name = None
    best_model = None
    best_performance = -99999
    best_model_param = None

    for model_name, model in list_of_tuned_model.items():
        if model['valid_auc'] > best_performance:
            best_model_name = model_name
            best_model = model['model']
            best_performance = model['valid_auc']
            best_model_param = model['best_params']

    # Dump the best model
    joblib.dump(best_model, params['best_model_path'])

    # Print
    print('=============================================')
    print('Best model        :', best_model_name)
    print('Metric score      :', best_performance)
    print('Best model params :', best_model_param)
    print('=============================================')

    if return_file:
        return best_model

# %%
best_model = get_best_model()
# Out:
# =============================================
# Best model        : KNeighborsClassifier
# Metric score      : 0.5
# Best model params : {'n_neighbors': 50}
# =============================================

# %%
THRESHOLD = np.linspace(0, 1, 100)

# %%
def get_best_threshold(return_file=True):
    """Function to tune & get the best decision threshold"""
    # Load data & model
    x_valid = joblib.load(params['valid_feng_set_path'][0])
    y_valid = joblib.load(params['valid_feng_set_path'][1])
    best_model = joblib.load(params['best_model_path'])

    # Get the proba pred
    y_pred_proba = best_model.predict_proba(x_valid)[:, 1]

    # Initialize
    metric_threshold = pd.Series([])
    
    # Optimize
    for threshold_value in THRESHOLD:
        # Get predictions
        y_pred = (y_pred_proba >= threshold_value).astype(int)

        # Get the F1 score
        metric_score = f1_score(y_valid, y_pred, average='macro')

        # Add to the storage
        metric_threshold[metric_score] = threshold_value

    # Find the threshold @max metric score
    metric_score_max_index = metric_threshold.index.max()
    best_threshold = metric_threshold[metric_score_max_index]
    print('=============================================')
    print('Best threshold :', best_threshold)
    print('Metric score   :', metric_score_max_index)
    print('=============================================')
    
    # Dump file
    joblib.dump(best_threshold, params['best_threshold_path'])

    if return_file:
        return best_threshold

# %%
get_best_threshold()
# Out:
# C:\Users\ThinkPad\AppData\Local\Temp\ipykernel_10080\231352802.py:12: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   metric_threshold = pd.Series([])
# =============================================
# Best threshold : 0.595959595959596
# Metric score   : 0.4910941475826972
# =============================================
# 0.595959595959596
